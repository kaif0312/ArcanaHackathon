# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif0312/ArcanaHackathon/blob/main/for_jango.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

# Read the JSON file
with open('/content/2022_1.json', 'r') as file: # put your transcript file here to play around
    data = json.load(file)

# Extract the values of the name, age, and city keys
symbol = data['symbol']
quarter = data['quarter']
year = data['year']
content = data['content']

# Print the values
print(symbol)
print(quarter)
print(year)
print(content)
# Out:
# AAPL
# 1
# 2022
# Operator: Good day, and welcome to the Apple Q1 FY 2022 Earnings Conference Call. Today's call is being recorded.  At this time, for opening remarks and introductions, I would like to turn the call over to Tejas Gala, Director of Investor Relations and Corporate Finance. Please go ahead.
# ...

# %%
sentences = nltk.sent_tokenize(content)

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/ProsusAI/finbert"
headers = {"Authorization": f"Bearer {'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'}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

output_tone = query(sentences)

# %%
print(output_tone)
# Out:
# [[{'label': 'neutral', 'score': 0.6171625852584839}, {'label': 'positive', 'score': 0.3699791431427002}, {'label': 'negative', 'score': 0.012858359143137932}], [{'label': 'neutral', 'score': 0.9384378790855408}, {'label': 'negative', 'score': 0.040284059941768646}, {'label': 'positive', 'score': 0.021278003230690956}], [{'label': 'neutral', 'score': 0.9247157573699951}, {'label': 'positive', 'score': 0.06464854627847672}, {'label': 'negative', 'score': 0.0106356767937541}], [{'label': 'neutral', 'score': 0.9280334711074829}, {'label': 'positive', 'score': 0.05631401762366295}, {'label': 'negative', 'score': 0.015652472153306007}], [{'label': 'positive', 'score': 0.6727190017700195}, {'label': 'neutral', 'score': 0.315777063369751}, {'label': 'negative', 'score': 0.011503959074616432}], [{'label': 'positive', 'score': 0.6249982714653015}, {'label': 'neutral', 'score': 0.3597583770751953}, {'label': 'negative', 'score': 0.01524343155324459}], [{'label': 'neutral', 'score': 0.9325774908
# ...

# %%
max_score = -1
filtered_output_tone = []

for sublist in output_tone:
    for dictionary in sublist:
        if dictionary['score'] > max_score:
            max_score = dictionary['score']
    
    filtered_output_tone.append([d for d in sublist if d['score'] == max_score])
    max_score = -1

print(filtered_output_tone)
# Out:
# [[{'label': 'neutral', 'score': 0.6171625852584839}], [{'label': 'neutral', 'score': 0.9384378790855408}], [{'label': 'neutral', 'score': 0.9247157573699951}], [{'label': 'neutral', 'score': 0.9280334711074829}], [{'label': 'positive', 'score': 0.6727190017700195}], [{'label': 'positive', 'score': 0.6249982714653015}], [{'label': 'neutral', 'score': 0.9325774908065796}], [{'label': 'neutral', 'score': 0.9114649295806885}], [{'label': 'neutral', 'score': 0.9438475966453552}], [{'label': 'negative', 'score': 0.821073055267334}], [{'label': 'neutral', 'score': 0.9482077360153198}], [{'label': 'neutral', 'score': 0.9396138191223145}], [{'label': 'neutral', 'score': 0.9221003651618958}], [{'label': 'positive', 'score': 0.8168769478797913}], [{'label': 'positive', 'score': 0.8982242345809937}], [{'label': 'positive', 'score': 0.952353835105896}], [{'label': 'positive', 'score': 0.8910011053085327}], [{'label': 'positive', 'score': 0.9163196682929993}], [{'label': 'negative', 'score': 0.842
# ...

# %%
pos = 0
neg = 0
neut = 0
pos_state = []
neg_state = []
neut_state = []

# %%
for i,val in enumerate(filtered_output_tone):
  if(val[0]['label'] == 'positive'):
    pos = pos + 1
    pos_state.append([sentences[i], i])
  elif(val[0]['label'] == 'negative'):
    neg = neg + 1
    neg_state.append([sentences[i], i ])
  else:
    neut = neut + 1
    neut_state.append([sentences[i],i ])

# %%
for i in pos_state:
  print(i)
# Out:
# ['Tejas Gala: Thank you.', 4]
# ['Good afternoon, and thank you for joining us.', 5]
# ['Tim Cook: Thank you, Tejas, and good afternoon.', 13]
# ["Today, we are proud to announce Apple's biggest quarter ever.", 14]
# ['Through the busy holiday season, we set an all-time revenue record of nearly $124 billion, up 11% from last year and better than we had expected at the beginning of the quarter.', 15]
# ['And we are pleased to see that our active installed base of devices is now at a new record with more than 1.8 billion devices.', 16]
# ['We set all-time records for both developed and emerging markets and saw revenue growth across all of our product categories, except for iPad, which we said would be supply constrained.', 17]
# ['On behalf of all of us at Apple, I want to extend our deep gratitude to the scientists, doctors, nurses and so many others on the front lines of combating COVID-19.', 21]
# ...

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/yiyanghkust/finbert-fls"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output_fls = query(sentences)

# %%
print(output_fls)
# Out:
# [[{'label': 'Not FLS', 'score': 0.9778333306312561}, {'label': 'Specific FLS', 'score': 0.011123297736048698}, {'label': 'Non-specific FLS', 'score': 0.011043478734791279}], [{'label': 'Not FLS', 'score': 0.9522666335105896}, {'label': 'Non-specific FLS', 'score': 0.029798321425914764}, {'label': 'Specific FLS', 'score': 0.017935097217559814}], [{'label': 'Not FLS', 'score': 0.7297608852386475}, {'label': 'Non-specific FLS', 'score': 0.1384141743183136}, {'label': 'Specific FLS', 'score': 0.13182498514652252}], [{'label': 'Not FLS', 'score': 0.8361353278160095}, {'label': 'Non-specific FLS', 'score': 0.10540730506181717}, {'label': 'Specific FLS', 'score': 0.05845737084746361}], [{'label': 'Not FLS', 'score': 0.8651885986328125}, {'label': 'Non-specific FLS', 'score': 0.07001207768917084}, {'label': 'Specific FLS', 'score': 0.06479931622743607}], [{'label': 'Not FLS', 'score': 0.9742113947868347}, {'label': 'Non-specific FLS', 'score': 0.014120418578386307}, {'label': 'Specific FLS',
# ...

# %%
max_score = -1
filtered_output_fls = []

for sublist in output_fls:
    for dictionary in sublist:
        if dictionary['score'] > max_score:
            max_score = dictionary['score']
    
    filtered_output_fls.append([d for d in sublist if d['score'] == max_score])
    max_score = -1

print(filtered_output_fls)
# Out:
# [[{'label': 'Not FLS', 'score': 0.9778333306312561}], [{'label': 'Not FLS', 'score': 0.9522666335105896}], [{'label': 'Not FLS', 'score': 0.7297608852386475}], [{'label': 'Not FLS', 'score': 0.8361353278160095}], [{'label': 'Not FLS', 'score': 0.8651885986328125}], [{'label': 'Not FLS', 'score': 0.9742113947868347}], [{'label': 'Not FLS', 'score': 0.8188161849975586}], [{'label': 'Non-specific FLS', 'score': 0.6147453188896179}], [{'label': 'Not FLS', 'score': 0.7098913192749023}], [{'label': 'Non-specific FLS', 'score': 0.9126244783401489}], [{'label': 'Not FLS', 'score': 0.9463931322097778}], [{'label': 'Not FLS', 'score': 0.9049801826477051}], [{'label': 'Not FLS', 'score': 0.8389332294464111}], [{'label': 'Not FLS', 'score': 0.9686207175254822}], [{'label': 'Not FLS', 'score': 0.9358304142951965}], [{'label': 'Not FLS', 'score': 0.9762475490570068}], [{'label': 'Not FLS', 'score': 0.9156996011734009}], [{'label': 'Not FLS', 'score': 0.9808319211006165}], [{'label': 'Not FLS', 'sc
# ...

# %%
FLS = 0 
FLSNot = 0
fls_statements = []
Notfls_statements = []

# %%
for i,val in enumerate(filtered_output_fls):
  if(val[0]['label'] == 'Specific FLS'):
    FLS = FLS+1
    fls_statements.append([sentences[i],i])
  elif(val[0]['label'] == 'Not FLS'):
    FLSNot = FLSNot +1
    Notfls_statements.append([sentences[i],i])
print("No of FLS statements = ",FLS,"\n","No of Not FLS statements = ",FLSNot, "\n",)
# Out:
# No of FLS statements =  19
#  No of Not FLS statements =  396

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/yiyanghkust/finbert-esg"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output_esg = query(sentences)

# %%
max_score = -1
filtered_output_esg = []

for sublist in output_esg:
    for dictionary in sublist:
        if dictionary['score'] > max_score:
            max_score = dictionary['score']
    
    filtered_output_esg.append([d for d in sublist if d['score'] == max_score])
    max_score = -1

print(filtered_output_esg)
# Out:
# [[{'label': 'None', 'score': 0.9827027320861816}], [{'label': 'None', 'score': 0.9858701229095459}], [{'label': 'None', 'score': 0.9651098251342773}], [{'label': 'None', 'score': 0.9660466313362122}], [{'label': 'None', 'score': 0.9802348613739014}], [{'label': 'None', 'score': 0.9240974187850952}], [{'label': 'None', 'score': 0.6030789017677307}], [{'label': 'None', 'score': 0.9654766917228699}], [{'label': 'None', 'score': 0.9927632212638855}], [{'label': 'None', 'score': 0.9948931932449341}], [{'label': 'None', 'score': 0.9908432960510254}], [{'label': 'None', 'score': 0.9934399724006653}], [{'label': 'None', 'score': 0.9800496101379395}], [{'label': 'None', 'score': 0.975854218006134}], [{'label': 'None', 'score': 0.8928858637809753}], [{'label': 'None', 'score': 0.9882388114929199}], [{'label': 'None', 'score': 0.6660222411155701}], [{'label': 'None', 'score': 0.9057629108428955}], [{'label': 'None', 'score': 0.9936425685882568}], [{'label': 'Social', 'score': 0.9850766062736511
# ...

# %%
env = 0
soc = 0
gov = 0
esg_none = 0
environment_stmts = []
social_stmts = []
gov_stmts = []

# %%
for i,val in enumerate(filtered_output_esg):
  if(val[0]['label'] == 'Environment'):
    env = env+1
    environment_stmts.append([sentences[i],i])
  elif(val[0]['label'] == 'Social'):
    soc = soc +1
    social_stmts.append([sentences[i],i])
  elif(val[0]['label'] == 'Governance'):
    gov = gov + 1 
    gov_stmts.append(sentences[i])

# %%
for i in social_stmts:
  print(i)
# Out:
# ['Before I discuss our results in greater detail, I want to first acknowledge the toll that COVID continues to have on communities around the world.', 19]
# ['In many places, case counts are higher and health systems more strained than at any point throughout the pandemic.', 20]
# ['On behalf of all of us at Apple, I want to extend our deep gratitude to the scientists, doctors, nurses and so many others on the front lines of combating COVID-19.', 21]
# ["And while I can't say it gets any easier, I can say I'm incredibly proud of the way our teams have come together and continue to innovate on behalf of our customers.", 23]
# ['A few weeks ago, we marked the 15th anniversary of the day Steve revealed iPhone to the world.', 24]
# ['We knew that we had the beginnings of something fundamentally transformative, though none of us could have predicted the incredible and meaningful impact it would have on all of our lives.', 25]
# ...

# %%
for i in fls_statements:
  print(i)
# Out:
# ['People expect Apple to solve hard problems with easy to use products.', 31]
# ['This initiative will help young people across the U.S. learn to code on iPad using our Everyone Can Code curriculum.', 67]
# ['To celebrate Black History Month, we will be releasing a special edition Apple Watch Black Unity Braided Solo Loop and a matching Unity Lights Watch Face.', 70]
# ['We expect to achieve solid year-over-year revenue growth and set a March quarter revenue record despite significant supply constraints, which we estimate to be less than what we experienced during the December quarter.', 133]
# ['We expect our revenue growth rate to decelerate from the December quarter, primarily due to 2 factors.', 134]
# ['As a result of the different launch timing, we will face a more challenging year-over-year compare.', 139]
# ['Second, we expect foreign exchange to be a 3-point headwind when compared to the December quarter growth rate.', 140]
# ...

# %%
for i in pos_state:
  print(i)
# Out:
# ['Tejas Gala: Thank you.', 4]
# ['Good afternoon, and thank you for joining us.', 5]
# ['Tim Cook: Thank you, Tejas, and good afternoon.', 13]
# ["Today, we are proud to announce Apple's biggest quarter ever.", 14]
# ['Through the busy holiday season, we set an all-time revenue record of nearly $124 billion, up 11% from last year and better than we had expected at the beginning of the quarter.', 15]
# ['And we are pleased to see that our active installed base of devices is now at a new record with more than 1.8 billion devices.', 16]
# ['We set all-time records for both developed and emerging markets and saw revenue growth across all of our product categories, except for iPad, which we said would be supply constrained.', 17]
# ['On behalf of all of us at Apple, I want to extend our deep gratitude to the scientists, doctors, nurses and so many others on the front lines of combating COVID-19.', 21]
# ...
